# %%
import re

#names, teams, objectives, KRs, tasks

#text and regex characters at the respective beginning and ending of required strings
beg = [r'\w\w\w \d+th\n+', r'Team:', r'Objective:|O:', r'KR:', r'Task:|Tasks:|Task\(s\):'] 
end = [r' \[\d+:\d\d AM| \[\d+:\d\d PM', r'Objective:|O:', r'KR:', r'Tasks:|Task:|Task\(s\):', r':heavy']

# %%
#text to be searched through

text = '''
Nov 6th
Ayoola [4:41 AM]
Check in and out 12/6
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1) CL: 7/10
Tasks:
1. Finished Practical Activity Instructions (100%) (1 hour)
2. Practical Activity Justifications (100%) (1 hour)
3. R&D meeting (100%)(1 hour) (edited) 
:heavy

Nov 6th
Heejin [4:41 AM]
Check in/out (12/10)
Team: S&O
O: To equip youth with ingrained knowledge of systems thinking.
KR(P1): A co-designing process for solutions for wicked problems that instills systems thinking.
KR(P2): A systemic strategy and operations structure for implementing the CWIST model.

Task(s):
1. No task
:heavy

Nov 6th
Ayoola [4:43 AM]
Check in and out 12/9
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1) CL: 7/10
Tasks: No work done
:heavy

Nov 6th
Ayoola [4:43 AM]
Check in and out 12/8
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1) CL: 7/10
Tasks: No work done
:heavy

Nov 6th
Ayoola [4:43 AM]
Check in and out 12/7
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1) CL: 7/10
Tasks: No work done
:heavy

Nov 6th
Ayoola [4:43 AM]
Check in and out 12/10
Team: AO
O: Facilitate and ensure the work efficiency of SAYDS teams
KR: Outline of specific tasks for everyone for each team to achieve their OKRs
Task: Collect and archive daily OKRs for KR efficiency for previous weeks (100%) (2 hours)
:heavy

Nov 6th
Ayoola [4:43 AM]
Check in and out 12/10
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1) CL: 7/10
Tasks:
1. Meeting with Edu on practical activities (100%) (0.33 h)
:heavy

Nov 6th
Jess Zier [10:15 AM]
Check in and out 12/10
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1) CL: 7/10
Tasks:
1. Correct network diagram from last week (100%) - 0.5 hours
2. Start concept descriptions (20%) - 0.5 hours
:heavy

Nov 6th
Levy [11:41 AM]
Check-out 12/10
Team: S&O
*Objective:* To help teams in creating things that will be used in securing resources for activities that will instill systems thinking for youth.
*KR:* Edition 1 of the applied complexity thinking manual is revised and completed. (Ddl 12/22; Conf. 8/10)
Task: Revise the complexity manual. (Not much done)
:heavy

Nov 6th
Levy [11:41 AM]
Check-out 12/10
Team: S&O
*Objective:* To help teams in creating things that will be used in securing resources for activities that will instill systems thinking for youth.
*KR:* Edition 1 of the applied complexity thinking manual is revised and completed. (Ddl 12/22; Conf. 8/10)
Task: Complete the theoretical framework for systems thinking activities. (2hrs of reviewing some crucial literature) (edited) 
:heavy

Nov 6th
Eduardo [3:26 PM]
Check in and out 12/10
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1) CL: 7/10
Tasks: Meeting with Ayoola on task distribution (0.3 hours) (50%) (edited) 
:heavy

Nov 6th
Heejin [4:54 AM]
Check in/out (12/11)
Team: S&O
O: To equip youth with ingrained knowledge of systems thinking.
KR(P1): A co-designing process for solutions for wicked problems that instills systems thinking.
KR(P2): A systemic strategy and operations structure for implementing the CWIST model.

Task(s):
1. No task
:heavy

Nov 6th
Jess Zier [7:54 AM]
Check in and out 12/11
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1) CL: 7/10
Tasks: Concept descriptions (100%) - 4 hours (edited) 
:heavy

Nov 6th
Eduardo [8:23 AM]
Check in and out 12/11
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1) CL: 7/10
Tasks: Meeting with Ayoola on task distribution (0.3 hours) (100%)
:heavy

Nov 6th
Perpetua Muthoni [9:06 AM]
Check-in/ Check-out(12/12)
Team: Tech
O: Set up the web platform to facilitate communication
KR: Populate the website with the required content
Tasks: Meeting with Levy(1 hour) Editing(2 hours)
:heavy

Nov 6th
Ayoola [9:14 AM]
Check in and out 12/11
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1) CL: 7/10
Tasks: Meeting with Edu on task distribution (0.33 hours) (100%)
:heavy

Nov 6th
dennis [12:11 PM]
Check in and out 12/11
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer.  (December 1) CL: 7/10
Tasks:
1. Idea brainstorm for group activity example with classmate + online research of examples of teaching activities (100%) (2 hours)
:heavy

Nov 6th
dennis [12:11 PM]
Check in and out 12/11
Team: S&O
O: To equip youth with ingrained knowledge of systems thinking.
KR: A systemic strategy and operations structure for implementing the CWIST model.
Task:
1. Special project w/ Prof. Odera on SAYDS future strategy; conducted informational interview (ongoing) (3 hours) (edited) 
:heavy

Nov 6th
Ayoola [11:16 PM]
Check in and out 12/12
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1) CL: 7/10
Tasks:
1. Working on creating practical activities for concepts (1 hour) (100%)
2. Meeting with Edu to discuss concepts (1 hour) (100%)
:heavy

Nov 6th
Ayoola [11:16 PM]
Check in and out 12/12
Team: AO
O: Facilitate and ensure the work efficiency of SAYDS teams
KR: Outline of specific tasks for everyone for each team to achieve their OKRs
Task: Analyse archived daily OKRs for KR efficiency for previous weeks (2 hours) (100%)
:heavy


Nov 6th
Eduardo [11:49 PM]
Check in and out 12/12
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1) CL: 7/10
Tasks:
1. Work on practical activities (2 hours) (40%)
2. Meeting with Ayoola for feedback and moving practical activities (1 hour) (100%)
:heavy

Nov 6th
dennis [2:27 AM]
Check in and out 12/12
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1) CL: 7/10
Tasks:
1. Work on group learning activities (2.5 hours) (100%)
2. Testing activities w/ classmates + integrating feedback (0.5hours) (100%) (edited) 
:heavy

Nov 6th
Heejin [3:31 AM]
Check in/out (12/12)
Team: S&O
O: To equip youth with ingrained knowledge of systems thinking.
KR(P1): A co-designing process for solutions for wicked problems that instills systems thinking.
KR(P2): A systemic strategy and operations structure for implementing the CWIST model.

Task(s):
1. No task
:heavy

Nov 6th
anvitg [4:15 PM]
Check in and out 12/10
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1) CL: 7/10
Tasks: Meeting with Dennis on task distribution (0.5 hours) (100%)
:heavy

Nov 6th
anvitg [4:15 PM]
Check in and out 12/11
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1) CL: 7/10
Tasks: Work on individual activities task for Stage 3 (50%) - 2 hrs
:heavy

Nov 6th
anvitg [4:15 PM]
Check in and out 12/12
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1) CL: 7/10
Tasks:
1. Work on individual learning activities (2.5 hours) (80%)
:heavy


Nov 6th
Valentina Liu [9:50 PM]
Check in and out 12/11
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer.  (December 1) CL: 7/10
Tasks:
1. no work
:heavy

Nov 6th
Valentina Liu [9:50 PM]
Check in and out 12/12
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer.  (December 1) CL: 7/10
Tasks:
1. no work
:heavy

Nov 6th
Valentina Liu [9:50 PM]
Check in  12/13
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer.  (December 1) CL: 7/10
Tasks:
1. design team map for next semester 0%
2. write up 2 pages 0%
3. write the semester schedule for north florida program
4. RD team meeting 0%
5. go through stage 3 materials 0%
6. revise manual 0% (edited) 
:heavy

Nov 6th
anvitg [11:17 PM]
Check in and out 12/13
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1) CL: 7/10
Tasks:
1. Work on individual learning activities (2 hours) (100%) 2. RD Meeting (1hr) (edited) 
:heavy

Nov 6th
dennis [11:48 PM]
Check in and out 12/13
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1) CL: 7/10
Tasks:
1. RD team meeting (1hr) (100%)
:heavy

Nov 6th
Eduardo [12:41 AM]
Check in and out 12/13
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1) CL: 7/10
Tasks:
1. Work on practical activities (2 hours) (100%)
2. Second meeting with Ayoola for feedback and improving practical activities (0.3 hours) (100%)
3. Compiling final document, giving feedback, re-structuring, and adding content  (1.5 hours) (100%)
4. R&D Meeting (1 hour) (100%) (edited) 
:heavy


Nov 6th
Valentina Liu [1:52 AM]
Check out 12/13
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer.  (December 1) CL: 7/10
Tasks:
1. design team map for next semester 100% 1h
2. write up 2 pages 100% 2h
3. write the semester schedule for north florida program 100% 2h
4. RD team meeting 100% 1h
5. go through stage 3 materials 100% 1h
6. revise manual 100% 2h (edited) 
:heavy

Nov 6th
Heejin [7:36 AM]
Check in/out (12/13)
Team: S&O
O: To equip youth with ingrained knowledge of systems thinking.
KR(P1): A co-designing process for solutions for wicked problems that instills systems thinking.
KR(P2): A systemic strategy and operations structure for implementing the CWIST model.

Task(s):
1. No task
:heavy

Nov 6th
dennis [10:34 AM]
Check in/out (12/13)
Team: S&O
O: To equip youth with ingrained knowledge of systems thinking.
KR(P1): A co-designing process for solutions for wicked problems that instills systems thinking.
KR(P2): A systemic strategy and operations structure for implementing the CWIST model.

Task(s):
1. No work scheduled for today
:heavy

Nov 6th
Jess Zier [10:38 AM]
Check in/out (12/13)
Team: S&O
O: To equip youth with ingrained knowledge of systems thinking.
KR(P1): A co-designing process for solutions for wicked problems that instills systems thinking.
KR(P2): A systemic strategy and operations structure for implementing the CWIST model.

Task(s):
1. R&D meeting (100%) - 1 hour
2. Correcting concepts (50%) 1 hour
:heavy

Nov 6th
Perpetua Muthoni [10:39 AM]
Check-in/ Check-out(12/13)
Team: Tech
O: Set up the web platform to facilitate communication
KR: Populate the website with the required content(Create an MVP)
Tasks: Write and edit web content, edit the website design (4 hours) 95% done (edited) 
:heavy

Nov 6th
Ayoola [8:14 PM]
Check in and out 12/13
Team: R&D
O: Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23) CL: 7/10
P2. Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1) CL: 7/10
Tasks:
1. Work on practical activities (2 hours) (100%)
2. Second meeting with Edu for feedback and improving practical activities (0.3 hours) (100%)
3. R&D Meeting (1 hour) (100%)
:heavy
'''

# %%
#replacing unwanted things in the using a dictionary

#replace initial[x] with final[x]
initial = ['P2.', '*', '(Ddl 12/22; Conf. 8/10)', '\nKR(P2): ', '(P1)', '(edited)', 'CL: 7/10']
final = ['KR:', '','','','','','','','','','']
initial_to_final = dict(zip(initial, final))
for initial, final in initial_to_final.items():
    text = text.replace(initial, final)
#print(text)

# %%
#changing slacknames to real names using a dictionary of names

slacknames = ['brianwahome254', 'anvitg', 'dennis', 'Jess Zier', 'Kimberley Kudwoli', 'Perpetua Muthoni', 
             'Sofia Camussi', 'Valentina Liu']
realnames = ['Brian', 'Anvit', 'Dennis', 'Jess', 'Kimberley', 'Perpetua', 'Sofia', 'Valentina']
slack_to_real = dict(zip(slacknames, realnames))
for slackname, realname in slack_to_real.items():
    text = text.replace(slackname, realname)

# %%
#finding the strings required and adding them to their respective lists

names = []; teams = []; objectives = []; KRs = []; tasks = []

biglist = [names, teams, objectives, KRs, tasks]

for x in range(len(biglist)): 
    list2 = []
    matches2 = re.compile(beg[x]).finditer(text)
    for match in matches2: 
        list2.append(list(match.span()))
    #if x>1:
    #print(len(list2))

    list3 = []
    matches3 = re.compile(end[x]).finditer(text)
    for match in matches3: 
        list3.append(list(match.span()))
    #print(len(list3))

    for y in range(len(list2)): 
        abc = text[list2[y][1]:list3[y][0]]
        abc = abc.replace('\n', '')
        biglist[x].append(abc)
    
    
    #print(biglist[x])

    
#checking that all lists have the same number of elements

print(len(names))
print(len(teams))
print(len(objectives))
print(len(KRs))
print(len(tasks))
# Out:
# 38
# 38
# 38
# 38
# 38

# %%
#dates require special treatment

dates = []

matches = re.compile(r'\d\d/\d+').finditer(text)
for match in matches: 
    dates.append(text[match.span()[0]:match.span()[1]])
print((dates))
# Out:
# ['12/6', '12/10', '12/9', '12/8', '12/7', '12/10', '12/10', '12/10', '12/10', '12/10', '12/10', '12/11', '12/11', '12/11', '12/12', '12/11', '12/11', '12/11', '12/12', '12/12', '12/12', '12/12', '12/12', '12/10', '12/11', '12/12', '12/11', '12/12', '12/13', '12/13', '12/13', '12/13', '12/13', '12/13', '12/13', '12/13', '12/13', '12/13']

# %%
import csv

newfile = 'output1.csv'
with open(newfile, 'w', newline = '') as csvfile:
    filewriter = csv.writer(csvfile, quoting=csv.QUOTE_MINIMAL)
    filewriter.writerow(dates)
    filewriter.writerow(names)
    filewriter.writerow(teams)
    filewriter.writerow(objectives)
    filewriter.writerow(KRs)
    filewriter.writerow(tasks)

# %%
#transposes rows and columns

a = zip(*csv.reader(open(newfile, "r")))
csv.writer(open("output2.csv", "w", newline = '')).writerows(a)

# %%
#shows csv files

import pandas as pd

def showcsv(csvfile): 
    dataframe = pd.read_csv(csvfile)
    print(dataframe)

# %%
showcsv('output2.csv')
# Out:
#      12/6     Ayoola    R&D  \
# 0   12/10     Heejin    S&O
# 1    12/9     Ayoola    R&D
# 2    12/8     Ayoola    R&D
# 3    12/7     Ayoola    R&D
# 4   12/10     Ayoola     AO
# 5   12/10     Ayoola    R&D
# 6   12/10       Jess    R&D
# 7   12/10       Levy    S&O
# 8   12/10       Levy    S&O
# 9   12/10    Eduardo    R&D
# 10  12/11     Heejin    S&O
# 11  12/11       Jess    R&D
# 12  12/11    Eduardo    R&D
# 13  12/12   Perpetua   Tech
# 14  12/11     Ayoola    R&D
# 15  12/11     Dennis    R&D
# 16  12/11     Dennis    S&O
# 17  12/12     Ayoola    R&D
# 18  12/12     Ayoola     AO
# 19  12/12    Eduardo    R&D
# 20  12/12     Dennis    R&D
# 21  12/12     Heejin    S&O
# 22  12/10      Anvit    R&D
# 23  12/11      Anvit    R&D
# 24  12/12      Anvit    R&D
# 25  12/11  Valentina    R&D
# 26  12/12  Valentina    R&D
# 27  12/13  Valentina    R&D
# 28  12/13      Anvit    R&D
# 29  12/13     Dennis    R&D
# 30  12/13    Eduardo    R&D
# 31  12/13  Valentina    R&D
# 32  12/13     Heejin    S&O
# 33  12/13     Dennis    S&O
# 34  12/13       Jess    S&O
# 35  12/13   Perpetua   Tech
# 36  12/13     Ayoola    R&D
#
#     Produce all the materials needed to work with the youth group in carrying out a systematic diagnosis of the complex education problem that the schoolgirls face. (Nov 26 - Dec 23)   \
# 0    To equip youth with ingrained knowledge of sy...
# 1    Produce all the materials needed to work with...
# 2    Produce all the materials needed to work with...
# 3    Produce all the materials needed to work with...
# 4    Facilitate and ensure the work efficiency of ...
# 5    Produce all the materials needed to work with...
# 6    Produce all the materials needed to work with...
# 7    To help teams in creating things that will be...
# 8    To help teams in creating things that will be...
# 9    Produce all the materials needed to work with...
# 10   To equip youth with ingrained knowledge of sy...
# 11   Produce all the materials needed to work with...
# 12   Produce all the materials needed to work with...
# 13   Set up the web platform to facilitate communi...
# 14   Produce all the materials needed to work with...
# 15   Produce all the materials needed to work with...
# 16   To equip youth with ingrained knowledge of sy...
# 17   Produce all the materials needed to work with...
# 18   Facilitate and ensure the work efficiency of ...
# 19   Produce all the materials needed to work with...
# 20   Produce all the materials needed to work with...
# 21   To equip youth with ingrained knowledge of sy...
# 22   Produce all the materials needed to work with...
# 23   Produce all the materials needed to work with...
# 24   Produce all the materials needed to work with...
# 25   Produce all the materials needed to work with...
# 26   Produce all the materials needed to work with...
# 27   Produce all the materials needed to work with...
# 28   Produce all the materials needed to work with...
# 29   Produce all the materials needed to work with...
# 30   Produce all the materials needed to work with...
# 31   Produce all the materials needed to work with...
# 32   To equip youth with ingrained knowledge of sy...
# 33   To equip youth with ingrained knowledge of sy...
# 34   To equip youth with ingrained knowledge of sy...
# 35   Set up the web platform to facilitate communi...
# 36   Produce all the materials needed to work with...
#
#     Produce materials for Stage 1 that provides knowledge on the concepts, the activities they need to carry out, and the questions they need to answer. (December 1)   \
# 0    A co-designing process for solutions for wick...
# 1    Produce materials for Stage 1 that provides k...
# 2    Produce materials for Stage 1 that provides k...
# 3    Produce materials for Stage 1 that provides k...
# 4    Outline of specific tasks for everyone for ea...
# 5    Produce materials for Stage 1 that provides k...
# 6    Produce materials for Stage 1 that provides k...
# 7    Edition 1 of the applied complexity thinking ...
# 8    Edition 1 of the applied complexity thinking ...
# 9    Produce materials for Stage 1 that provides k...
# 10   A co-designing process for solutions for wick...
# 11   Produce materials for Stage 1 that provides k...
# 12   Produce materials for Stage 1 that provides k...
# 13     Populate the website with the required content
# 14   Produce materials for Stage 1 that provides k...
# 15   Produce materials for Stage 1 that provides k...
# 16   A systemic strategy and operations structure ...
# 17   Produce materials for Stage 1 that provides k...
# 18   Outline of specific tasks for everyone for ea...
# 19   Produce materials for Stage 1 that provides k...
# 20   Produce materials for Stage 1 that provides k...
# 21   A co-designing process for solutions for wick...
# 22   Produce materials for Stage 1 that provides k...
# 23   Produce materials for Stage 1 that provides k...
# 24   Produce materials for Stage 1 that provides k...
# 25   Produce materials for Stage 1 that provides k...
# 26   Produce materials for Stage 1 that provides k...
# 27   Produce materials for Stage 1 that provides k...
# 28   Produce materials for Stage 1 that provides k...
# 29   Produce materials for Stage 1 that provides k...
# 30   Produce materials for Stage 1 that provides k...
# 31   Produce materials for Stage 1 that provides k...
# 32   A co-designing process for solutions for wick...
# 33   A co-designing process for solutions for wick...
# 34   A co-designing process for solutions for wick...
# 35   Populate the website with the required conten...
# 36   Produce materials for Stage 1 that provides k...
#
#    1. Finished Practical Activity Instructions (100%) (1 hour)2. Practical Activity Justifications (100%) (1 hour)3. R&D meeting (100%)(1 hour)
# 0                                          1. No task
# 1                                        No work done
# 2                                        No work done
# 3                                        No work done
# 4    Collect and archive daily OKRs for KR efficie...
# 5   1. Meeting with Edu on practical activities (1...
# 6   1. Correct network diagram from last week (100...
# 7       Revise the complexity manual. (Not much done)
# 8    Complete the theoretical framework for system...
# 9    Meeting with Ayoola on task distribution (0.3...
# 10                                         1. No task
# 11            Concept descriptions (100%) - 4 hours
# 12   Meeting with Ayoola on task distribution (0.3...
# 13         Meeting with Levy(1 hour) Editing(2 hours)
# 14   Meeting with Edu on task distribution (0.33 h...
# 15  1. Idea brainstorm for group activity example ...
# 16  1. Special project w/ Prof. Odera on SAYDS fut...
# 17  1. Working on creating practical activities fo...
# 18   Analyse archived daily OKRs for KR efficiency...
# 19  1. Work on practical activities (2 hours) (40%...
# 20  1. Work on group learning activities (2.5 hour...
# 21                                         1. No task
# 22   Meeting with Dennis on task distribution (0.5...
# 23   Work on individual activities task for Stage ...
# 24  1. Work on individual learning activities (2.5...
# 25                                         1. no work
# 26                                         1. no work
# 27  1. design team map for next semester 0%2. writ...
# 28  1. Work on individual learning activities (2 h...
# 29                    1. RD team meeting (1hr) (100%)
# 30  1. Work on practical activities (2 hours) (100...
# 31  1. design team map for next semester 100% 1h2....
# 32                                         1. No task
# 33                     1. No work scheduled for today
# 34  1. R&D meeting (100%) - 1 hour2. Correcting co...
# 35   Write and edit web content, edit the website ...
# 36  1. Work on practical activities (2 hours) (100...

# %%
#creates list of names and dates
nameslist = ['Anvit', 'Ayoola', 'Brenda', 'Brian', 'Corrie', 'Dennis', 'Eduardo', 'Heejin', 'Jess', 'Kimberley', 'Levy', 
         'Lishu','Perpetua', 'Sofia', 'Valentina']

dateslist = []

lowerbound = 6
upperbound = 13

month = 12

while lowerbound <= upperbound:  
    adate = str(month) + '/' + str(lowerbound)
    dateslist.append(adate)
    lowerbound+=1

print(dateslist)
# Out:
# ['12/6', '12/7', '12/8', '12/9', '12/10', '12/11', '12/12', '12/13']

# %%
#checks if the individual checked in on a day

newfile = 'presentornot.csv'
with open(newfile, 'w', newline = '') as csvfile:
    filewriter = csv.writer(csvfile, quoting=csv.QUOTE_MINIMAL)
    filewriter.writerow(['date']+nameslist)
    for x in dateslist: 
        newlist = []
        for y in range(len(dates)): 
            if dates[y] == x: 
                newlist.append(names[y])
        #print(newlist)
        truelist = []
        truelist.append(x)
        for z in nameslist: 
            if z in newlist: 
                truelist.append('Yes')
            else: 
                truelist.append('No')
        #print(x, truelist)
        filewriter.writerow(truelist)

# %%
showcsv('presentornot.csv')
# Out:
#     date Anvit Ayoola Brenda Brian Corrie Dennis Eduardo Heejin Jess  \
# 0   12/6    No    Yes     No    No     No     No      No     No   No
# 1   12/7    No    Yes     No    No     No     No      No     No   No
# 2   12/8    No    Yes     No    No     No     No      No     No   No
# 3   12/9    No    Yes     No    No     No     No      No     No   No
# 4  12/10   Yes    Yes     No    No     No     No     Yes    Yes  Yes
# 5  12/11   Yes    Yes     No    No     No    Yes     Yes    Yes  Yes
# 6  12/12   Yes    Yes     No    No     No    Yes     Yes    Yes   No
# 7  12/13   Yes    Yes     No    No     No    Yes     Yes    Yes  Yes
#
#   Kimberley Levy Lishu Perpetua Sofia Valentina
# 0        No   No    No       No    No        No
# 1        No   No    No       No    No        No
# 2        No   No    No       No    No        No
# 3        No   No    No       No    No        No
# 4        No  Yes    No       No    No        No
# 5        No   No    No       No    No       Yes
# 6        No   No    No      Yes    No       Yes
# 7        No   No    No      Yes    No       Yes
